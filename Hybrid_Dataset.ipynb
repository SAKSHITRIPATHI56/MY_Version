# %% [markdown]
# ### IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set(color_codes=True)
import matplotlib.pyplot as plt
import pandas as pd 
from PIL import Image
from matplotlib.pyplot import figure
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ##   Datasets work:
# ### 1]IMAGE
# ### 2]AUDIO
# ### 3]VIDEO

# %% [markdown]
# ### 1] IMAGE

# %%
data=pd.read_csv('ANALYSIS/image.csv')

# %%
data.head()
# Out:
#    Unnamed: 0           original_file  size_of_file  resolution  retain_data  \
# 0           0  900-Men-in-Black-l.jpg        104772  900 x 1600          100
# 1           1            001 (36).jpg        121274  736 x 1240          100
# 2           2       1-1305251S305.jpg        108803  720 x 1280          100
# 3           3                 10.jpeg          9192   225 x 225          100
# 4           4                 11.jpeg          6989   225 x 225          100
#
#    loss_in_data  encrpyt_time  decrypt_time
# 0             0        16.293        38.498
# 1             0        20.330        50.236
# 2             0        17.540        40.156
# 3             0         0.539         0.622
# 4             0         0.459         0.456

# %%
#data.keys()
data.columns
# Out:
# Index(['Unnamed: 0', 'original_file', 'size_of_file', 'resolution',
#        'retain_data', 'loss_in_data', 'encrpyt_time', 'decrypt_time'],
#       dtype='object')

# %%
data.describe()
# Out:
#        Unnamed: 0   size_of_file  retain_data  loss_in_data  encrpyt_time  \
# count  201.000000     201.000000        201.0         201.0    201.000000
# mean   100.000000   98449.348259        100.0           0.0     17.375726
# std     58.167861   58180.487783          0.0           0.0     15.213497
# min      0.000000    2788.000000        100.0           0.0      0.344000
# 25%     50.000000   47913.000000        100.0           0.0      3.982000
# 50%    100.000000   96688.000000        100.0           0.0     12.676000
# 75%    150.000000  151760.000000        100.0           0.0     29.956000
# max    200.000000  201050.000000        100.0           0.0     55.397000
#
#        decrypt_time
# count    201.000000
# mean      43.884930
# std       39.669482
# min        0.213000
# 25%        8.749000
# 50%       31.770000
# 75%       77.449000
# max      133.836000

# %%
data.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0                  original_file  size_of_file   resolution  \
# 0             0         900-Men-in-Black-l.jpg        104772   900 x 1600
# 1             1                   001 (36).jpg        121274   736 x 1240
# 2             2              1-1305251S305.jpg        108803   720 x 1280
# 3             3                        10.jpeg          9192    225 x 225
# 4             4                        11.jpeg          6989    225 x 225
# ..          ...                            ...           ...          ...
# 196         196  arun thakur giveaway (18).jpg        134740  1080 x 1920
# 197         197   arun thakur giveaway (7).jpg        126831   750 x 1334
# 198         198  arun thakur giveaway (36).png         74895  1080 x 1920
# 199         199  arun thakur giveaway (37).png        197764  1080 x 1920
# 200         200  arun thakur giveaway (38).png        119204  1080 x 1920
#
# ...

# %%
data.shape
# Out:
# (201, 8)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0       0
# original_file    0
# size_of_file     0
# resolution       0
# retain_data      0
# loss_in_data     0
# encrpyt_time     0
# decrypt_time     0
# dtype: int64

# %%
data = pd.read_csv('ANALYSIS/image.csv',index_col=0)
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
plt.plot(data['size_of_file'], data['encrpyt_time'],'ro',label='Encryption') 
plt.plot(data['size_of_file'], data['decrypt_time'],'bo',label='Decryption')  
plt.legend()
plt.xlabel('Size of Image (bytes)') 
plt.ylabel('Time (seconds)') 
plt.title('Encryption-Decryption') 
#plt.show() 
plt.savefig('ANALYSIS/image_performance.png')

# %% [markdown]
# ### MATPLOT

# %%
plt.plot([1,2,3],[4,5,6])

# %%
plt.plot([1,2,3],[4,5,6],color='g')
plt.title("Basic")
plt.ylabel('Yaxis')
plt.xlabel('Xaxis')
plt.show()

# %%
plt.bar(data['encrpyt_time'],data['decrypt_time'],color='g')
# Out:
# <BarContainer object of 201 artists>

# %% [markdown]
# ### HISTOGRAM

# %%
plt.hist(data['size_of_file'],color='r')
# Out:
# (array([23., 18., 27., 18., 17., 23., 16., 20., 21., 18.]),
#  array([  2788. ,  22614.2,  42440.4,  62266.6,  82092.8, 101919. ,
#         121745.2, 141571.4, 161397.6, 181223.8, 201050. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data['encrpyt_time'])
# Out:
# (array([68., 27., 23., 18., 10., 14., 13., 17.,  8.,  3.]),
#  array([ 0.344 ,  5.8493, 11.3546, 16.8599, 22.3652, 27.8705, 33.3758,
#         38.8811, 44.3864, 49.8917, 55.397 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data['decrypt_time'])
# Out:
# (array([67., 25., 25., 17.,  8., 13., 11., 16., 11.,  8.]),
#  array([  0.213 ,  13.5753,  26.9376,  40.2999,  53.6622,  67.0245,
#          80.3868,  93.7491, 107.1114, 120.4737, 133.836 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### SCATTER PLOT

# %%
plt.scatter(data['encrpyt_time'],data['decrypt_time'],color='g')
plt.show()

# %%
plt.scatter(data['encrpyt_time'],data['original_file'])
plt.show()

# %% [markdown]
# ### SEABORN

# %% [markdown]
# ### HEATMAP

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### JOINT PLOT

# %%
sns.jointplot( data['decrypt_time'],data['original_file'])

# %%
sns.pairplot(data[['original_file', 'encrpyt_time', 'retain_data']])

# %%
sns.stripplot( data['encrpyt_time'], data['original_file'])
# Out:
# <AxesSubplot:xlabel='encrpyt_time', ylabel='original_file'>

# %% [markdown]
# ### COUNTPLOT

# %%
sns.countplot( x='retain_data',hue='original_file',data = data)
# Out:
# <AxesSubplot:xlabel='retain_data', ylabel='count'>

# %%
sns.pointplot(data['retain_data'], data['original_file'], hue=data['encrpyt_time'])
# Out:
# <AxesSubplot:xlabel='retain_data', ylabel='original_file'>

# %%
sns.lmplot(x="retain_data", y="encrpyt_time", data=data)

# %%
sns.lmplot(x="retain_data", y="encrpyt_time", hue="original_file", data=data)

# %% [markdown]
# ### DISTPLOT

# %%
sns.distplot(data['retain_data'])
# Out:
# <AxesSubplot:xlabel='retain_data', ylabel='Density'>

# %%
sns.distplot(data['retain_data'], kde=False, rug=True);

# %% [markdown]
# ### BOXPLOT

# %%
sns.boxplot(x='retain_data',y='encrpyt_time',data=data)
# Out:
# <AxesSubplot:xlabel='retain_data', ylabel='encrpyt_time'>

# %%
sns.boxplot(data['retain_data'], data['encrpyt_time'], hue=data['original_file'])
# Out:
# <AxesSubplot:xlabel='retain_data', ylabel='encrpyt_time'>

# %%
sns.boxplot(data['retain_data'], data['original_file'], hue=data['encrpyt_time'])
# Out:
# <AxesSubplot:xlabel='retain_data', ylabel='original_file'>

# %% [markdown]
# ### 2] AUDIO

# %%
dat=pd.read_csv('ANALYSIS/audio.csv')

# %%
dat.head()
# Out:
#                                 original_file  size_of_file  loss_in_data  \
# 0  5233 _1965_Aadhi-Raat-Ke-Baad--1965-_L.mp3         52512             0
# 1  5243 _1965_Aakash-Deep--1965-_Manna-De.mp3        180660             0
# 2  5332 _1965_Guide--1965-_SD-Burman_1965.mp3        157902             0
# 3  5408 _1965_Lutera--1965-_Laxmikant-Pya.mp3        167193             0
# 4  5634 _1966_Dulhan Ek Raat Ki (1966)_La.mp3        122406             0
#
#    retain_data  encrpyt_time  decrypt_time
# 0          100         4.429        10.063
# 1          100        46.754       109.582
# 2          100        33.227        86.334
# 3          100        41.369        95.484
# 4          100        22.203        51.348

# %%
dat.columns
# Out:
# Index(['original_file', 'size_of_file', 'loss_in_data', 'retain_data',
#        'encrpyt_time', 'decrypt_time'],
#       dtype='object')

# %%
dat.describe()
# Out:
#         size_of_file  loss_in_data  retain_data  encrpyt_time  decrypt_time
# count     142.000000         142.0        142.0    142.000000    142.000000
# mean   132892.070423           0.0        100.0     25.026627     64.198704
# std     44827.197587           0.0          0.0     13.699402     36.177359
# min      9152.000000           0.0        100.0      0.550000      0.618000
# 25%    100573.500000           0.0        100.0     13.556750     34.118250
# 50%    134299.500000           0.0        100.0     23.106000     59.387000
# 75%    167185.500000           0.0        100.0     35.277750     92.346250
# max    199757.000000           0.0        100.0     48.590000    129.245000

# %%
dat.info
# Out:
# <bound method DataFrame.info of                                   original_file  size_of_file  loss_in_data  \
# 0    5233 _1965_Aadhi-Raat-Ke-Baad--1965-_L.mp3         52512             0
# 1    5243 _1965_Aakash-Deep--1965-_Manna-De.mp3        180660             0
# 2    5332 _1965_Guide--1965-_SD-Burman_1965.mp3        157902             0
# 3    5408 _1965_Lutera--1965-_Laxmikant-Pya.mp3        167193             0
# 4    5634 _1966_Dulhan Ek Raat Ki (1966)_La.mp3        122406             0
# ..                                          ...           ...           ...
# 137  0711 _1952_Anhonee 1952__Yeh Jhilmil K.mp3        119387             0
# 138  0712 _1952_Anhonee 1952__Yeh Jhilmil K.mp3        116411             0
# 139  0993 _1953_Aas 1953__Music_Shankar Jai.mp3        185108             0
# 140  1005 _1953_Anarkali 1953_1422_14 Dance.mp3        156056             0
# 141  1009 _1953_Anarkali 1953_1822_18 Nisha.mp3        104369             0
#
# ...

# %%
dat.shape
# Out:
# (142, 6)

# %%
dat.isnull().sum()
# Out:
# original_file    0
# size_of_file     0
# loss_in_data     0
# retain_data      0
# encrpyt_time     0
# decrypt_time     0
# dtype: int64

# %%
dat = pd.read_csv('ANALYSIS/audio.csv')
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
dat.sort_values(by="encrpyt_time")
plt.plot(data['size_of_file'], data['encrpyt_time'],'ro',label='Encryption') 
plt.plot(data['size_of_file'], data['decrypt_time'],'bo',label='Decryption') 
plt.legend()

  
plt.xlabel('Size of Audio (bytes)') 
plt.ylabel('Time (seconds)') 
plt.title('Encryption-Decryption') 
# plt.show() 
plt.savefig('ANALYSIS/audio_performance.png')

# %% [markdown]
# ### MATPLOT

# %%
plt.bar(dat['encrpyt_time'],dat['decrypt_time'],color='g')
# Out:
# <BarContainer object of 142 artists>

# %% [markdown]
# ### HISTOGRAM

# %%
plt.hist(dat['size_of_file'],color='r')
# Out:
# (array([ 2.,  2.,  6., 10., 20., 24., 12., 22., 17., 27.]),
#  array([  9152. ,  28212.5,  47273. ,  66333.5,  85394. , 104454.5,
#         123515. , 142575.5, 161636. , 180696.5, 199757. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(dat['encrpyt_time'])
# Out:
# (array([ 9., 11., 23., 20., 12.,  9., 18., 10.,  9., 21.]),
#  array([ 0.55 ,  5.354, 10.158, 14.962, 19.766, 24.57 , 29.374, 34.178,
#         38.982, 43.786, 48.59 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### SCATTER PLOT

# %%
plt.scatter(dat['encrpyt_time'],dat['decrypt_time'],color='g')
plt.show()

# %%
#plt.scatter(dat['encrpyt_time'],dat['original_file'])
#plt.show()

# %%
plt.scatter(dat['original_file'],dat['encrpyt_time'])
plt.show()

# %% [markdown]
# ### 3] VIDEO

# %%
df=pd.read_csv('ANALYSIS/video.csv')

# %%
df.head()
# Out:
#                                        original_file  size_of_file  \
# 0  1_30 am - i hear my roommate sucking ass at gu...        183083
# 1                             A PARK IN BOTSWANA.mp4        395086
# 2                                  Cat Faceplant.mp4        329006
# 3                         Colin's Bear Animation.mp4        101244
# 4                         Eminem is not a rapper.mp4         76239
#
#    retain_data  loss_in_data  encrpyt_time  decrypt_time
# 0        100.0           0.0        46.003       113.598
# 1        100.0           0.0       197.739       503.219
# 2        100.0           0.0       127.759       346.724
# 3        100.0           0.0        14.607        34.712
# 4        100.0           0.0         8.236        20.182

# %%
df.columns
# Out:
# Index(['original_file', 'size_of_file', 'retain_data', 'loss_in_data',
#        'encrpyt_time', 'decrypt_time'],
#       dtype='object')

# %%
df.describe()
# Out:
#         size_of_file  retain_data  loss_in_data  encrpyt_time  decrypt_time
# count      18.000000         18.0          18.0     18.000000     18.000000
# mean   245549.833333        100.0           0.0     84.229500    223.330611
# std     97694.402743          0.0           0.0     57.569683    152.599596
# min     76239.000000        100.0           0.0      8.236000     20.182000
# 25%    186596.000000        100.0           0.0     46.437750    116.824000
# 50%    231525.000000        100.0           0.0     64.479500    172.904000
# 75%    338521.250000        100.0           0.0    135.672250    367.096250
# max    395086.000000        100.0           0.0    197.739000    503.219000

# %%
df.info
# Out:
# <bound method DataFrame.info of                                         original_file  size_of_file  \
# 0   1_30 am - i hear my roommate sucking ass at gu...        183083
# 1                              A PARK IN BOTSWANA.mp4        395086
# 2                                   Cat Faceplant.mp4        329006
# 3                          Colin's Bear Animation.mp4        101244
# 4                          Eminem is not a rapper.mp4         76239
# 5                                     Go! Bwaaaah.mp4        140068
# 6                                     Ha Ha Ha Ha.mp4        208507
# 7   Hey, you shaved real good today! - Neil deGras...        142851
# 8         Jay Z's Accountant - super short comedy.mp4        341693
# 9              Jesus is the Bread (ORIGINAL) 2006.mp4        342440
# 10  Neil deGrasse Tyson explains the future of spa...        233134
# 11  Price is Right contestant gets outed! Sort of.mp4        365984
# ...

# %%
df.shape
# Out:
# (18, 6)

# %%
df.isnull().sum()
# Out:
# original_file    0
# size_of_file     0
# retain_data      0
# loss_in_data     0
# encrpyt_time     0
# decrypt_time     0
# dtype: int64

# %%
df = pd.read_csv('ANALYSIS/video.csv')
figure(num=None, figsize=(4.5, 3.2), dpi=80, facecolor='w', edgecolor='k')
plt.plot(df['size_of_file'], df['encrpyt_time'],'ro',label='Encryption') 
plt.plot(df['size_of_file'], df['decrypt_time'],'bo',label='Decryption') 
  
plt.xlabel('Size of Video (bytes)') 
plt.ylabel('Time (seconds)') 
  
# giving a title to my graph 
plt.title('Encryption-Decryption') 
  
# function to show the plot 
# plt.show() 
plt.savefig('ANALYSIS/video_performance.png')

# %% [markdown]
# ### MATPLOT

# %%
plt.bar(df['encrpyt_time'],df['decrypt_time'],color='g')
# Out:
# <BarContainer object of 18 artists>

# %% [markdown]
# ### HISTOGRAM

# %%
plt.hist(df['size_of_file'],color='r')
# Out:
# (array([2., 0., 2., 3., 3., 1., 0., 2., 2., 3.]),
#  array([ 76239. , 108123.7, 140008.4, 171893.1, 203777.8, 235662.5,
#         267547.2, 299431.9, 331316.6, 363201.3, 395086. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['encrpyt_time'])
# Out:
# (array([4., 1., 4., 2., 0., 1., 3., 2., 0., 1.]),
#  array([  8.236 ,  27.1863,  46.1366,  65.0869,  84.0372, 102.9875,
#         121.9378, 140.8881, 159.8384, 178.7887, 197.739 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### SCATTER PLOT

# %%
plt.scatter(df['encrpyt_time'],df['decrypt_time'],color='g')
plt.show()

# %%
plt.scatter(df['encrpyt_time'],df['original_file'])
plt.show()
